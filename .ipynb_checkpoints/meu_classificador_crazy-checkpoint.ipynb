# %%
# Clone the repository if running in Colab and install all the dependencies
if 'google.colab' in str(get_ipython()):
    import sys
    import os
    try:
      # !git clone https://github.com/lasseufpa/ml4comm-icc21.git
    except:
      print("ml4comm-icc21 is already in the contents")
    # !pip install -r /content/ml4comm-icc21/requirements.txt  &>/dev/null
    sys.path.append(os.path.abspath('/content/ml4comm-icc21'))

# %%
import sys
import os

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import pandas as pd
import numpy as np

from commpy.channels import SISOFlatChannel

sys.path.append(os.path.abspath('ml4comm'))
from ml4comm.qam_crazy import crazy_channel_propagate
import model_selection

np.random.seed(42) # Important

from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
def main():
    train_sizes = [i for i in ransge(100, 3001, 100)]
    model_selection.evaluate_model(name='decision_tree', channel='crazy', train_sizes=train_sizes)

if __name__ == '__main__':
    main()
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 96
# rank 1: {'max_depth': 150} - SER: 10.421%
# rank 2: {'max_depth': 80} - SER: 11.474%
# rank 3: {'max_depth': 100} - SER: 12.526%
# rank 3: {'max_depth': 300} - SER: 12.526%
# rank 5: {'max_depth': 200} - SER: 13.579%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 192
# rank 1: {'max_depth': 80} - SER: 3.657%
# rank 1: {'max_depth': 300} - SER: 3.657%
# rank 3: {'max_depth': 100} - SER: 4.710%
# rank 3: {'max_depth': 150} - SER: 4.710%
# rank 3: {'max_depth': 200} - SER: 4.710%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 288
# rank 1: {'max_depth': 80} - SER: 5.203%
# rank 1: {'max_depth': 100} - SER: 5.203%
# rank 1: {'max_depth': 150} - SER: 5.203%
# rank 1: {'max_depth': 200} - SER: 5.203%
# rank 1: {'max_depth': 300} - SER: 5.203%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 400
# rank 1: {'max_depth': 80} - SER: 4.250%
# rank 1: {'max_depth': 100} - SER: 4.250%
# rank 1: {'max_depth': 150} - SER: 4.250%
# rank 1: {'max_depth': 300} - SER: 4.250%
# rank 5: {'max_depth': 200} - SER: 4.500%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 496
# rank 1: {'max_depth': 80} - SER: 5.036%
# rank 2: {'max_depth': 150} - SER: 5.238%
# rank 2: {'max_depth': 300} - SER: 5.238%
# rank 4: {'max_depth': 200} - SER: 5.240%
# rank 5: {'max_depth': 100} - SER: 5.642%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 592
# rank 1: {'max_depth': 150} - SER: 4.559%
# rank 2: {'max_depth': 80} - SER: 4.561%
# rank 3: {'max_depth': 300} - SER: 4.727%
# rank 4: {'max_depth': 200} - SER: 4.729%
# rank 5: {'max_depth': 100} - SER: 4.897%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 688
# rank 1: {'max_depth': 80} - SER: 3.781%
# rank 1: {'max_depth': 200} - SER: 3.781%
# rank 3: {'max_depth': 100} - SER: 3.927%
# rank 3: {'max_depth': 300} - SER: 3.927%
# rank 5: {'max_depth': 150} - SER: 4.217%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 800
# rank 1: {'max_depth': 80} - SER: 4.000%
# rank 2: {'max_depth': 100} - SER: 4.000%
# rank 2: {'max_depth': 150} - SER: 4.000%
# rank 4: {'max_depth': 200} - SER: 4.125%
# rank 4: {'max_depth': 300} - SER: 4.125%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 896
# rank 1: {'max_depth': 200} - SER: 3.907%
# rank 2: {'max_depth': 80} - SER: 3.908%
# rank 3: {'max_depth': 100} - SER: 4.019%
# rank 4: {'max_depth': 150} - SER: 4.242%
# rank 4: {'max_depth': 300} - SER: 4.242%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 992
# rank 1: {'max_depth': 80} - SER: 3.328%
# rank 2: {'max_depth': 150} - SER: 3.428%
# rank 3: {'max_depth': 300} - SER: 3.529%
# rank 4: {'max_depth': 100} - SER: 3.529%
# rank 4: {'max_depth': 200} - SER: 3.529%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 1088
# rank 1: {'max_depth': 300} - SER: 3.585%
# rank 2: {'max_depth': 100} - SER: 3.586%
# rank 3: {'max_depth': 80} - SER: 3.676%
# rank 4: {'max_depth': 150} - SER: 3.677%
# rank 4: {'max_depth': 200} - SER: 3.677%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 1200
# rank 1: {'max_depth': 80} - SER: 3.500%
# rank 1: {'max_depth': 150} - SER: 3.500%
# rank 3: {'max_depth': 300} - SER: 3.583%
# rank 4: {'max_depth': 100} - SER: 3.750%
# rank 4: {'max_depth': 200} - SER: 3.750%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 1296
# rank 1: {'max_depth': 300} - SER: 3.086%
# rank 2: {'max_depth': 150} - SER: 3.164%
# rank 3: {'max_depth': 100} - SER: 3.318%
# rank 4: {'max_depth': 80} - SER: 3.395%
# rank 5: {'max_depth': 200} - SER: 3.473%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 1392
# rank 1: {'max_depth': 200} - SER: 3.304%
# rank 2: {'max_depth': 100} - SER: 3.376%
# rank 3: {'max_depth': 300} - SER: 3.376%
# rank 4: {'max_depth': 80} - SER: 3.448%
# rank 5: {'max_depth': 150} - SER: 3.520%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 1488
# rank 1: {'max_depth': 300} - SER: 3.226%
# rank 2: {'max_depth': 200} - SER: 3.293%
# rank 3: {'max_depth': 80} - SER: 3.360%
# rank 3: {'max_depth': 100} - SER: 3.360%
# rank 5: {'max_depth': 150} - SER: 3.427%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 1600
# rank 1: {'max_depth': 100} - SER: 3.250%
# rank 2: {'max_depth': 80} - SER: 3.312%
# rank 2: {'max_depth': 200} - SER: 3.312%
# rank 2: {'max_depth': 300} - SER: 3.312%
# rank 5: {'max_depth': 150} - SER: 3.375%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 1696
# rank 1: {'max_depth': 80} - SER: 3.066%
# rank 1: {'max_depth': 200} - SER: 3.066%
# rank 3: {'max_depth': 300} - SER: 3.243%
# rank 4: {'max_depth': 100} - SER: 3.420%
# rank 4: {'max_depth': 150} - SER: 3.420%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 1792
# rank 1: {'max_depth': 200} - SER: 2.789%
# rank 2: {'max_depth': 80} - SER: 2.901%
# rank 3: {'max_depth': 150} - SER: 2.901%
# rank 4: {'max_depth': 300} - SER: 2.957%
# rank 5: {'max_depth': 100} - SER: 2.957%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 1888
# rank 1: {'max_depth': 300} - SER: 3.071%
# rank 2: {'max_depth': 100} - SER: 3.230%
# rank 2: {'max_depth': 150} - SER: 3.230%
# rank 4: {'max_depth': 200} - SER: 3.389%
# rank 5: {'max_depth': 80} - SER: 3.547%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 2000
# rank 1: {'max_depth': 100} - SER: 2.650%
# rank 2: {'max_depth': 300} - SER: 2.800%
# rank 3: {'max_depth': 200} - SER: 2.800%
# rank 4: {'max_depth': 150} - SER: 2.850%
# rank 5: {'max_depth': 80} - SER: 2.950%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 2096
# rank 1: {'max_depth': 100} - SER: 2.672%
# rank 2: {'max_depth': 150} - SER: 2.815%
# rank 3: {'max_depth': 200} - SER: 2.815%
# rank 4: {'max_depth': 80} - SER: 2.863%
# rank 5: {'max_depth': 300} - SER: 3.006%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 2192
# rank 1: {'max_depth': 100} - SER: 3.010%
# rank 1: {'max_depth': 200} - SER: 3.010%
# rank 3: {'max_depth': 80} - SER: 3.010%
# rank 4: {'max_depth': 150} - SER: 3.010%
# rank 5: {'max_depth': 300} - SER: 3.101%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 2288
# rank 1: {'max_depth': 80} - SER: 2.796%
# rank 2: {'max_depth': 150} - SER: 2.840%
# rank 2: {'max_depth': 300} - SER: 2.840%
# rank 4: {'max_depth': 200} - SER: 2.840%
# rank 5: {'max_depth': 100} - SER: 2.927%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 2400
# rank 1: {'max_depth': 200} - SER: 2.958%
# rank 2: {'max_depth': 80} - SER: 3.000%
# rank 2: {'max_depth': 300} - SER: 3.000%
# rank 4: {'max_depth': 150} - SER: 3.042%
# rank 5: {'max_depth': 100} - SER: 3.042%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 2496
# rank 1: {'max_depth': 80} - SER: 2.564%
# rank 2: {'max_depth': 200} - SER: 2.604%
# rank 3: {'max_depth': 150} - SER: 2.644%
# rank 4: {'max_depth': 300} - SER: 2.764%
# rank 5: {'max_depth': 100} - SER: 2.764%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 2592
# rank 1: {'max_depth': 300} - SER: 2.507%
# rank 2: {'max_depth': 100} - SER: 2.507%
# rank 3: {'max_depth': 150} - SER: 2.507%
# rank 4: {'max_depth': 80} - SER: 2.584%
# rank 5: {'max_depth': 200} - SER: 2.623%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 2688
# rank 1: {'max_depth': 150} - SER: 2.492%
# rank 2: {'max_depth': 100} - SER: 2.604%
# rank 3: {'max_depth': 200} - SER: 2.827%
# rank 4: {'max_depth': 80} - SER: 2.827%
# rank 5: {'max_depth': 300} - SER: 2.902%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 2800
# rank 1: {'max_depth': 150} - SER: 2.786%
# rank 2: {'max_depth': 80} - SER: 2.821%
# rank 2: {'max_depth': 100} - SER: 2.821%
# rank 4: {'max_depth': 300} - SER: 2.893%
# rank 5: {'max_depth': 200} - SER: 2.929%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 2900
# rank 1: {'max_depth': 80} - SER: 2.517%
# rank 2: {'max_depth': 300} - SER: 2.552%
# rank 3: {'max_depth': 100} - SER: 2.621%
# rank 4: {'max_depth': 200} - SER: 2.724%
# rank 5: {'max_depth': 150} - SER: 2.828%
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ------------ decision_tree ---------------
# TRAIN SIZE: 3000
# rank 1: {'max_depth': 300} - SER: 2.667%
# rank 2: {'max_depth': 100} - SER: 2.733%
# rank 2: {'max_depth': 150} - SER: 2.733%
# rank 4: {'max_depth': 200} - SER: 2.800%
# rank 5: {'max_depth': 80} - SER: 2.867%
